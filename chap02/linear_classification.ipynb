# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X,y =  make_blobs(random_state=42)
mglearn.discrete_scatter(X[:,0],X[:,1],y,)

plt.xlabel("Feature0")
plt.ylabel("Feature1")
plt.legend(["class 0","class 1","class 2"])

# %%
from sklearn.calibration import LinearSVC


linear_svm = LinearSVC().fit(X,y)
print("Cofficient shaoe : ",linear_svm.coef_.shape)
print(linear_svm.coef_)
print("intercept shape : ",linear_svm.intercept_.shape)
print(linear_svm.intercept_)
# Out:
# Cofficient shaoe :  (3, 2)
# [[-0.17492412  0.23140766]
#  [ 0.47622012 -0.06936786]
#  [-0.18914207 -0.20400079]]
# intercept shape :  (3,)
# [-1.07745775  0.13139239 -0.08604962]

# %%
mglearn.discrete_scatter(X[])
